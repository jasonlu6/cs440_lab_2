# %% [markdown]
# # Lab 2 - Python Classification/Visualization
#
#
# ## Popular Python toolboxes/libraries
# - Numpy: http://www.numpy.org/
# - Scipy: https://www.scipy.org/scipylib/
# - Pandas: http://pandas.pydata.org/
# - SciKit-Learn: http://scikit-learn.org/stable/
# - matplotlib: https://matplotlib.org/

# %%
# Import Python libraries
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Analysis Basics

# %%
# Read csv data file
hw_df = pd.read_csv("heights_weights_genders.csv")
hw_df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
# Basic Statistics

# %%
# Group
hw_df.groupby('Gender')["Height"].mean()
# Out:
# Gender
# Female    63.708774
# Male      69.026346
# Name: Height, dtype: float64

# %%
# Visualization
from matplotlib.colors import ListedColormap
cm_bright = ListedColormap(['#FF0000', '#0000FF'])

plt.figure()
plt.scatter(hw_df.Weight, hw_df.Height, c=[cm_bright.colors[i] for i in hw_df.Gender=="Male"])
plt.show()

# %% [markdown]
# ## Classification Model Training
# **Classification** tries to predict, which of a small set of classes, a sample in a population belongs to. Mathematically, the aim is to find $y$, a **label** based on knowing a feature vector $X$.

# %%
# Data Standardization
sub_df = hw_df[['Height','Weight']]
sub_df_std = (sub_df - sub_df.mean()) / sub_df.std()
sub_df_std.head()
# Out:
#      Height    Weight
# 0  1.943964  2.505672
# 1  0.627505  0.027099
# 2  2.012343  1.597726
# 3  1.393991  1.825131
# 4  0.913375  1.398680

# %%
# Split training and testing data
from sklearn.model_selection import train_test_split
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-27-e760d98f1f94> in <module>()
#       1 # Split training and testing data
# ----> 2 from sklearn.model_selection import train_test_split
#       3 Xtrain, Xtest, ytrain, ytest = train_test_split(X, y)
#
# ImportError: No module named sklearn.model_selection

# %%
# Train Logistic Regression Model
from sklearn import linear_model
df = linear_model.LogisticRegression()
clf.fit(Xtrain, ytrain)
ypred = clf.predict(Xtest)

# %% [markdown]
# ## Model Evaluation

# %%
# Training and test accuracy
training_accuracy = clf.score(Xtrain, ytrain)
test_accuracy = clf.score(Xtest, ytest)
print ("Accuracy on training data: %0.4f" % (training_accuracy))
print ("Accuracy on test data:     %0.4f" % (test_accuracy))

# %%
# Confusion Matrix
from sklearn.metrics import confusion_matrix
cnf_matrix = confusion_matrix(ytest, ypred)

# %%
# Confusion Matrix Visualization
# http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html#sphx-glr-auto-examples-model-selection-plot-confusion-matrix-py
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# Plot non-normalized confusion matrix

% matplotlib inline

plt.figure()
plot_confusion_matrix(cnf_matrix, classes=['Male', 'Female'], 
                      title='Confusion matrix')
plt.show()

# %%
# Precision, Recall, Sensitivity and Specificity
precision = tp / (tp + fp)
recall = tp / (tp + fn)
sensitivity = 
specificity = 
print ("Precision:   %0.4f" % (precision))
print ("Recall:      %0.4f" % (recall))
print ("Sensitivity: %0.4f" % (sensitivity))
print ("Specificity: %0.4f" % (specificity))

# %% [markdown]
# ## To do: Try Iris Dataset
# 1. Load SciKit-learn Iris dataset and explore the data
# 2. Visualize the data (use the first or last two features)
# 3. Split the data and train logistic regression model
# 4. Plot confusion matrix and evaluate the model

# %%
# Load iris data

from sklearn import datasets
iris = datasets.load_iris()
iris_df = pd.DataFrame(data = np.c_iris[['data'], iris['target']], 
                       columns = iris['feature_names'] + ['target'])
iris_df.head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-28-43068eedea1d> in <module>()
#       1 # Load iris data
#       2
# ----> 3 from sklearn import datasets
#       4 iris = datasets.load_iris()
#       5 iris_df = pd.DataFrame(data = np.c_iris[['data'], iris['target']],
#
# ImportError: No module named sklearn

# %%
# Visualization
# %matplotlib inline
from matplotlib.colors import ListedColormap
cm_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

plt.figure(figsize = (10,8))
plt.scatter(iris_df['petal length (cm)'], iris_df['petal width (cm)'], c=[cm_bold.colors[int(i)] for i in iris_df.target], alpha=0.5)
plt.show()

# %%
# Train model
from sklearn import linear_model

# %%
# Model Evaluation
